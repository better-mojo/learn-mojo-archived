# %% [markdown]
# # Mojo Notes:
#
# - Mojo 内测阶段，示例代码。
# - 注意： 当前阶段的示例，不代表正式版之后的语法。（当前不支持的特性，未来可能正确支持）
#
# ## print
#
# - 暂时不支持 f-string。

# %%
print("hello mojo")

# %%
# 目前 Mojo 不支持
print("hello {}".format("mojo"))

# %%
print(f"hello {'mojo'}")

# %%
print("hello %s" % "mojo")

# %% [markdown]
# ## import python libs
#
#
# - bs4 正常使用
# - requests, 不能使用， 猜测是禁用了。（保护 playground 机器安全）

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

"""


from PythonInterface import Python


var bs4 = Python.import_module("bs4")
var builtins = Python.import_module("builtins")
var bprint = builtins.print


var soup = bs4.BeautifulSoup(html_doc)

var result = soup.prettify()

builtins.print(result)

bprint("print end!")

# %%
from PythonInterface import Python

var requests = Python.import_module("requests")
var builtins = Python.import_module("builtins")
var bp = builtins.print


# x = requests.get('https://api.github.com/events')
x = requests.get('https://www.runoob.com/')


var result = x.text

bp(result)

# %%
# 导入 requests 包
import requests

# 发送请求
x = requests.get('https://www.runoob.com/')

# 返回网页内容
print(x.text)

# %% [markdown]
# ## 其他测试：
